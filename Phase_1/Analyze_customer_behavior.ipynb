# %% [markdown]
# ## **Import Libraries:**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer

# %%
ideal = pd.read_csv("/content/Hackathon_Ideal_Data.csv")
mapping = pd.read_csv("/content/Hackathon_Mapping_File.csv")
validation = pd.read_csv("/content/Hackathon_Validation_Data.csv")
working = pd.read_csv("/content/Hackathon_Working_Data.csv")

# %%
ideal.head()
# Out:
#   MONTH STORECODE  QTY  VALUE                GRP               SGRP  \
# 0    M1        P1   25     83  HAIR CONDITIONERS  HAIR CONDITIONERS
# 1    M1        P1    6     22  HAIR CONDITIONERS  HAIR CONDITIONERS
# 2    M1        P1    4     15  HAIR CONDITIONERS  HAIR CONDITIONERS
# 3    M1        P1   15     60  HAIR CONDITIONERS  HAIR CONDITIONERS
# 4    M1        P2    0      0  HAIR CONDITIONERS  HAIR CONDITIONERS
#
#                SSGRP                         CMP         MBRD  \
# 0  HAIR CONDITIONERS  HINDUSTAN UNILEVER LIMITED         DOVE
# 1  HAIR CONDITIONERS  HINDUSTAN UNILEVER LIMITED         DOVE
# 2  HAIR CONDITIONERS  HINDUSTAN UNILEVER LIMITED         DOVE
# 3  HAIR CONDITIONERS               L'OREAL INDIA      GARNIER
# 4  HAIR CONDITIONERS  HINDUSTAN UNILEVER LIMITED  CLINIC PLUS
#
#                      BRD
# 0  DOVE HAIR FALL RESCUE
# 1    DOVE INTENSE REPAIR
# 2   DOVE OXYGEN MOISTURE
# 3                FRUCTIS
# 4            CLINIC PLUS

# %%
mapping.head()
# Out:
#               File Name Column Name           Column Description
# 0  Hackathon_Ideal_Data       MONTH        Month ID (M1, M2, M3)
# 1                   NaN   STORECODE  STORE CODE (P1, P2, …, P10)
# 2                   NaN         QTY                   Sales Unit
# 3                   NaN       VALUE                  Sales Value
# 4                   NaN         GRP                     Category

# %%
validation.head()
# Out:
#         ID STORECODE MONTH                       GRP
# 0  1112535        N1    M1       AFTER SHAVE LOTIONS
# 1  1112539        N1    M1    AGARBATTI & DHOOPBATTI
# 2  1112543        N1    M1  ALL AIR FRESHNERS(01/03)
# 3  1112547        N1    M1          ALL IODISED SALT
# 4  1112551        N1    M1                  ANTACIDS

# %%
working.head()
# Out:
#   MONTH STORECODE  DAY BILL_ID  BILL_AMT  QTY  VALUE  PRICE  \
# 0    M1        N1    4    T375     225.0  1.0  225.0  225.0
# 1    M1        N1    4    T379      95.0  1.0   95.0   95.0
# 2    M1        N1    4    T381      10.0  1.0   10.0   10.0
# 3    M1        N1    4    T382     108.0  1.0  108.0  108.0
# 4    M1        N1    4    T384      19.0  1.0   19.0   19.0
#
#                        GRP                     SGRP                    SSGRP  \
# 0     BUTTER MARGR  (4/94)                   BUTTER                   SALTED
# 1  CONFECTIONERY - ECLAIRS  CONFECTIONERY - ECLAIRS  CONFECTIONERY - ECLAIRS
# 2                CHOCOLATE         CHOCOLATE PANNED         CHOCOLATE PANNED
# 3             PACKAGED TEA               MAIN PACKS               MAIN PACKS
# 4         ALL IODISED SALT            POWDERED SALT            POWDERED SALT
#
#                       CMP           MBRD                 BRD
# 0               G C M M F           AMUL                AMUL
# 1             PARLE PRODS         MELODY    MELODY CHOCOLATY
# 2  MONDELEZ INTERNATIONAL  CADBURY SHOTS       CADBURY SHOTS
# 3      GUJ TEA PROCESSORS     WAGH BAKRI  WAGH BAKRI INSTANT
# 4               TATA CHEM           TATA           TATA SALT

# %%
ideal.shape
# Out:
# (14260, 10)

# %%
mapping.shape
# Out:
# (24, 3)

# %%
validation.shape
# Out:
# (2430, 4)

# %%
working.shape
# Out:
# (26985, 14)

# %%
ideal.describe()
# Out:
#                 QTY         VALUE
# count  14260.000000  14260.000000
# mean      16.354488    294.455330
# std       34.365583    760.129558
# min        0.000000      0.000000
# 25%        1.000000     10.000000
# 50%        4.000000     99.000000
# 75%       16.000000    283.000000
# max      641.000000  24185.000000

# %%
working.describe()
# Out:
#                 DAY      BILL_AMT           QTY         VALUE         PRICE
# count  26985.000000  26985.000000  26985.000000  26985.000000  26985.000000
# mean      15.167019    278.754206      4.105021     67.808551     52.812982
# std        8.956057    541.398504     95.666947    118.005978     84.987730
# min        1.000000      0.000000      0.500000      0.000000      0.000000
# 25%        7.000000     40.000000      1.000000     10.000000     10.000000
# 50%       14.000000    111.000000      1.000000     30.000000     22.000000
# 75%       23.000000    280.000000      2.000000     80.000000     64.000000
# max       31.000000   7292.000000  12000.000000   3150.000000   3150.000000

# %%
ideal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14260 entries, 0 to 14259
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   MONTH      14260 non-null  object
#  1   STORECODE  14260 non-null  object
#  2   QTY        14260 non-null  int64
#  3   VALUE      14260 non-null  int64
#  4   GRP        14260 non-null  object
#  5   SGRP       14260 non-null  object
#  6   SSGRP      14260 non-null  object
#  7   CMP        14260 non-null  object
#  8   MBRD       14260 non-null  object
#  9   BRD        14260 non-null  object
# dtypes: int64(2), object(8)
# memory usage: 1.1+ MB

# %%
working.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26985 entries, 0 to 26984
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   MONTH      26985 non-null  object
#  1   STORECODE  26985 non-null  object
#  2   DAY        26985 non-null  int64
#  3   BILL_ID    26985 non-null  object
#  4   BILL_AMT   26985 non-null  float64
#  5   QTY        26985 non-null  float64
#  6   VALUE      26985 non-null  float64
#  7   PRICE      26985 non-null  float64
#  8   GRP        26985 non-null  object
#  9   SGRP       26985 non-null  object
#  10  SSGRP      26985 non-null  object
#  11  CMP        26985 non-null  object
#  12  MBRD       26985 non-null  object
#  13  BRD        26985 non-null  object
# dtypes: float64(4), int64(1), object(9)
# memory usage: 2.9+ MB

# %% [markdown]
# ### **Data Preprocessing and Feature Engineering:**

# %%
imputer = SimpleImputer(strategy="mean")
ideal_filled = imputer.fit_transform(ideal.select_dtypes(include=['int','float']))
ideal_filled = pd.DataFrame(ideal_filled,columns=ideal.select_dtypes(include=['int','float']).columns)

# %%
# Data Cleaning, Normalization and Standardization
scaler = StandardScaler()
working_scaled = scaler.fit_transform(working.select_dtypes(include=['int','float']))
working_scaled = pd.DataFrame(working_scaled,columns=working.select_dtypes(include=['int','float']).columns)

# %%
encoder = OneHotEncoder()
ideal_encoded = pd.get_dummies(ideal.select_dtypes(include=['object']))

# %%
ideal_preprocessed = pd.concat([ideal_filled, ideal_encoded],axis=1)

# %%
print("Ideal data after preprocessing:")
ideal_preprocessed.head()
# Out:
# Ideal data after preprocessing:
#     QTY  VALUE  MONTH_M1  MONTH_M2  MONTH_M3  STORECODE_P1  STORECODE_P10  \
# 0  25.0   83.0      True     False     False          True          False
# 1   6.0   22.0      True     False     False          True          False
# 2   4.0   15.0      True     False     False          True          False
# 3  15.0   60.0      True     False     False          True          False
# 4   0.0    0.0      True     False     False         False          False
#
#    STORECODE_P2  STORECODE_P3  STORECODE_P4  ...  BRD_ZANDU  BRD_ZANDU GEL  \
# 0         False         False         False  ...      False          False
# 1         False         False         False  ...      False          False
# 2         False         False         False  ...      False          False
# 3         False         False         False  ...      False          False
# 4          True         False         False  ...      False          False
#
#    BRD_ZANDU ULTRA POWER  BRD_ZATPAT  BRD_ZED BLACK  \
# 0                  False       False          False
# 1                  False       False          False
# 2                  False       False          False
# 3                  False       False          False
# 4                  False       False          False
#
#    BRD_ZED BLACK  DEEP MOGRA  BRD_ZED BLACK DEEP GULAB  BRD_ZED BLACK MANTHAN  \
# 0                      False                     False                  False
# 1                      False                     False                  False
# 2                      False                     False                  False
# 3                      False                     False                  False
# 4                      False                     False                  False
#
#    BRD_ZED BLACK PANCHDEEP  BRD_ZOOPY
# 0                    False      False
# 1                    False      False
# 2                    False      False
# 3                    False      False
# 4                    False      False
#
# [5 rows x 3457 columns]

# %%
print("Working data after scaling:")
working_scaled.head()
# Out:
# Working data after scaling:
#         DAY  BILL_AMT       QTY     VALUE     PRICE
# 0 -1.246891 -0.099290 -0.032457  1.332088  2.026060
# 1 -1.246891 -0.339413 -0.032457  0.230429  0.496399
# 2 -1.246891 -0.496417 -0.032457 -0.489887 -0.503764
# 3 -1.246891 -0.315401 -0.032457  0.340595  0.649365
# 4 -1.246891 -0.479793 -0.032457 -0.413618 -0.397865

# %% [markdown]
# ## **Exploratory Data Analysis (EDA):**

# %%
working = pd.read_csv("/content/Hackathon_Working_Data.csv")

# %%
#plot the distribution of numeric columns
numeric_cols = ['BILL_AMT','QTY','VALUE','PRICE']
working[numeric_cols].hist(figsize=(10,8))
plt.tight_layout()
plt.show()

# %%
#plot the correlation heatmap of numeric columns
sns.heatmap(working[numeric_cols].corr(),annot=True, cmap='twilight')
plt.title("Correlation heatmap of numeric columns")
plt.show()

# %%
#count plots for categorical columns
categorical_cols = ['MONTH','STORECODE']
for col in categorical_cols:
  sns.countplot(data=working,x=col,order=working[col].value_counts().index)
  plt.xticks(rotation=45)
  plt.show()

# %%
plt.figure(figsize=(13,7))
categorical_cols = ['GRP']
for col in categorical_cols:
  sns.countplot(data=working,y=col,order=working[col].value_counts().index, palette='cubehelix')
  plt.yticks(fontsize=5)
  plt.show()

# %%
plt.figure(figsize=(13,7))
categorical_cols = ['SGRP']
for col in categorical_cols:
  sns.countplot(data=working,y=col,order=working[col].value_counts().index, palette='cubehelix')
  plt.yticks(fontsize=4)
  plt.show()

# %%
#box plot for identify outliers
sns.boxplot(data=working[numeric_cols])
plt.title("Box Plot of numeric columns")
plt.show()

# %%
sns.pairplot(working[numeric_cols],diag_kind='kde')
plt.suptitle("Pairwise Relationship between Numeric columns")
plt.show()

# %%
#customer segmentation with K-Means clustering

from sklearn.cluster import KMeans

# %%
x = working[['BILL_AMT','QTY']]

# %%
#standardize the features
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)

# %%
#Determine the optimal number of cluster using elbow method
wcss=[]
for i in range(1,11):
  kmeans = KMeans(n_clusters=i,init='k-means++',random_state=42)
  kmeans.fit(x_scaled)
  wcss.append(kmeans.inertia_)

# %%
plt.plot(range(1,11),wcss)
plt.title('Elbow Method')
plt.xlabel('Number of cluster')
plt.ylabel('WCSS')
plt.show()

# %%
#based on elbow method, choose the optimal number of clusters
n_clusters=3

# %%
#apply K-Means clustering
kmeans = KMeans(n_clusters, init='k-means++',random_state=42)
working['Cluster']=kmeans.fit_predict(x_scaled)

# %%
#Visualize cluster
sns.scatterplot(data=working, x='BILL_AMT',y='QTY',hue='Cluster',palette='crest')
plt.title("Customer Segmentation")
plt.xlabel('Total Transaction amount')
plt.ylabel('Total Quantity')
plt.legend(title='Cluster')
plt.show()

# %%
#Prediction Modeling

#create histogram for transaction amount and quantities
plt.subplot(1,2,1)
sns.histplot(working['BILL_AMT'],bins=30,kde=True)
plt.title("Distribution of transaction amount")

plt.subplot(1,2,2)
sns.histplot(working['QTY'],bins=20,kde=True)
plt.title("Distribution of transaction quantities")
plt.tight_layout()
plt.show()

# %%
#Boxplot for transaction amounts
sns.boxplot(y=working['BILL_AMT'])
plt.title("BoxPlot of tranaction amount")
plt.show()

# %%
#assuming 'MONTH' column represent the month
monthly_sales = working.groupby('MONTH').size()
monthly_sales.plot(kind='bar')
plt.title("Monthly transaction volumes")
plt.xlabel('Month')
plt.ylabel('Transaction volume')
plt.xticks(rotation=45)
plt.show()

# %%
#asssuming 'GRP' column represent product categories
top_categories = working['GRP'].value_counts().nlargest(10)
plt.figure(figsize=(12,6))
top_categories.plot(kind='bar')
plt.title("Top 10 Selling Product Categories")
plt.xlabel('Product category')
plt.ylabel('Number of transaction')
plt.xticks(rotation=45)
plt.show()

# %%
#conduct RFM analysis or clustring techniques
#here, we'll use RFM analysis as an example
#assuming 'STORECODE' represents unique customers

rfm_working = working.groupby('STORECODE').agg({
    'BILL_ID':'count',    #Frequency
    'BILL_AMT':'sum',     #Monetary
}).rename(columns={'BILL_ID':'Frequency','BILL_AMT':'Monetary'})

# %%
rfm_working
# Out:
#            Frequency    Monetary
# STORECODE
# N1              4583   626464.78
# N10             2169   550107.00
# N2              1331   794062.00
# N3              1793   494536.37
# N4              3212   872215.70
# N5              4431   695755.00
# N6              1185   366530.00
# N7              5625  1036821.74
# N8              1128   492817.35
# N9              1528  1592872.31

# %%
#visualize RFM segments
sns.scatterplot(data=rfm_working, x='Frequency',y='Monetary',palette='flare')
plt.title("RFM Segments")
plt.xlabel('Frequency')
plt.ylabel('Monetary')
plt.show()

# %%
sns.scatterplot(data=working, x='QTY',y='BILL_AMT',hue='MONTH',palette='Set1')
plt.title("Relationship between quantity and transaction amount")
plt.xlabel('Quantity')
plt.ylabel('Transaction amount')
plt.show()

# %%
sns.heatmap(working[['QTY','BILL_AMT','VALUE','PRICE']].corr(),annot=True,cmap='cividis')
plt.title("Correlation Heatmap")
plt.show()

# %%
#customer behaviour analysis
#for ideal data

#analyze purchasing pattern over time
sns.countplot(data=ideal, x='MONTH', order=ideal['MONTH'].value_counts().index)
plt.title("Purchasing pattern over time for IDEAL time")
plt.show()

# %%
#identify popular product categories
plt.figure(figsize=(15,10))
sns.countplot(data=ideal,y='GRP', order=ideal['GRP'].value_counts().index, palette='mako')
plt.title("Popular product categories for IDEAL data")
plt.xlabel('number of transaction')
plt.ylabel('product category')
plt.xticks(fontsize=7)
plt.yticks(fontsize=7)
plt.show()

# %%
#relationship between quantity and value
sns.scatterplot(data=ideal,x='QTY', y='VALUE',color='blue')
plt.title("Relationship betweeen Quantity and Value for IDEAL data")
plt.xlabel('quantity')
plt.ylabel('value')
plt.show()

# %%
#analyze the distribution of purchases across different stores
sns.countplot(data=ideal, x='STORECODE', order=ideal['STORECODE'].value_counts().index, palette='BuGn_r')
plt.title("Distribution of purchases across different stores for IDEAL data")
plt.xlabel('store code')
plt.ylabel('number of transction')
plt.show()

# %%
#for working data

#analyze purchasing pattern over time
sns.countplot(data=working, x='MONTH', order=working['MONTH'].value_counts().index)
plt.title("Purchasing pattern over time for WORKING data")
plt.show()

# %%
#identify popular product categories
plt.figure(figsize=(15,10))
sns.countplot(data=working,y='GRP', order=working['GRP'].value_counts().index, palette='mako')
plt.title("Popular product categories for WORKING data")
plt.xlabel('number of transaction')
plt.ylabel('product category')
plt.xticks(fontsize=7)
plt.yticks(fontsize=7)
plt.show()

# %%
#relationship between quantity and value
sns.scatterplot(data=working,x='QTY', y='VALUE',color='blue')
plt.title("Relationship betweeen Quantity and Value for WORKING data")
plt.xlabel('quantity')
plt.ylabel('value')
plt.show()

# %%
#analyze the distribution of purchases across different stores
sns.countplot(data=working, x='STORECODE', order=working['STORECODE'].value_counts().index, palette='BuGn_r')
plt.title("Distribution of purchases across different stores for WORKING data")
plt.xlabel('store code')
plt.ylabel('number of transction')
plt.show()

# %%
#visualization and reporting
sns.lineplot(data=working, x='DAY', y='BILL_AMT', hue='MONTH',ci=None)
plt.title("Trends in customer behavior for WORKING data")
plt.xlabel('day of month')
plt.ylabel('total bill amount')
plt.legend(title='month')
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
x=working_scaled.drop(columns=['PRICE'])
y=working_scaled['PRICE']

# %%
x_train,x_val_test,y_train,y_val_test = train_test_split(x,y,test_size=0.3,random_state=42)
x_val,x_test,y_val,y_test = train_test_split(x_val_test,y_val_test,test_size=0.5,random_state=42)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GRU

gru_model=Sequential([
    GRU(units=64,input_shape=(x_train.shape[1],1)),
    Dense(units=1)
])

# %%
gru_model.compile(optimizer='adam',loss='mean_squared_error')

# %%
gru_history=gru_model.fit(x_train.values.reshape((x_train.shape[0],x_train.shape[1],1)),
                          y_train.values,epochs=100,batch_size=32,validation_data=(x_val.values.reshape((x_val.shape[0],x_val.shape[1],1)),y_val.values))

test_loss=gru_model.evaluate(x_test.values.reshape((x_test.shape[0],x_test.shape[1],1)),y_test.values)
print("gru model test loss:",test_loss)
# Out:
# Epoch 1/100
# 591/591 [==============================] - 7s 7ms/step - loss: 0.3691 - val_loss: 0.2649
# Epoch 2/100
# 591/591 [==============================] - 3s 6ms/step - loss: 0.2954 - val_loss: 0.2710
# Epoch 3/100
# 591/591 [==============================] - 5s 9ms/step - loss: 0.2876 - val_loss: 0.2679
# Epoch 4/100
# 591/591 [==============================] - 4s 7ms/step - loss: 0.2843 - val_loss: 0.2500
# Epoch 5/100
# 591/591 [==============================] - 4s 6ms/step - loss: 0.2810 - val_loss: 0.2670
# Epoch 6/100
# 591/591 [==============================] - 5s 8ms/step - loss: 0.2725 - val_loss: 0.2599
# Epoch 7/100
# 591/591 [==============================] - 4s 7ms/step - loss: 0.2640 - val_loss: 0.2558
# Epoch 8/100
# 591/591 [==============================] - 3s 6ms/step - loss: 0.2529 - val_loss: 0.2607
# Epoch 9/100
# 591/591 [==============================] - 4s 6ms/step - loss: 0.2367 - val_loss: 0.2264
# Epoch 10/100
# 591/591 [==============================] - 5s 8ms/step - loss: 0.2232 - val_loss: 0.1990
# Epoch 11/100
# 591/591 [==============================] - 4s 7ms/step - loss: 0.2036 - val_loss: 0.1650
# Epoch 12/100
# 591/591 [==============================] - 4s 7ms/step - loss: 0.1836 - val_loss: 0.1320
# Epoch 13/100
# 591/591 [==============================] - 4s 8ms/step - loss: 0.1602 - val_loss: 0.1515
# Epoch 14/100
# 591/591 [==============================] - 4s 6ms/step - loss: 0.1404 - val_loss: 0.0898
# Epoch 15/100
# 591/591 [==============================] - 3s 6ms/step - loss: 0.1157 - val_loss: 0.0761
# Epoch 16/100
# 591/591 [==============================] - 3s 6ms/step - loss: 0.0947 - val_loss: 0.0629
# Epoch 17/100
# 591/591 [==============================] - 5s 8ms/step - loss: 0.0810 - val_loss: 0.0303
# Epoch 18/100
# 591/591 [==============================] - 3s 5ms/step - loss: 0.0642 - val_loss: 0.0266
# Epoch 19/100
# 591/591 [==============================] - 4s 6ms/step - loss: 0.0535 - val_loss: 0.0381
# Epoch 20/100
# 591/591 [==============================] - 4s 7ms/step - loss: 0.0460 - val_loss: 0.0145
# Epoch 21/100
# 591/591 [==============================] - 5s 8ms/step - loss: 0.0383 - val_loss: 0.0251
# Epoch 22/100
# 591/591 [==============================] - 4s 7ms/step - loss: 0.0317 - val_loss: 0.0120
# Epoch 23/100
# 591/591 [==============================] - 4s 6ms/step - loss: 0.0277 - val_loss: 0.0118
# Epoch 24/100
# 591/591 [==============================] - 5s 8ms/step - loss: 0.0267 - val_loss: 0.0092
# Epoch 25/100
# 591/591 [==============================] - 3s 6ms/step - loss: 0.0221 - val_loss: 0.0134
# Epoch 26/100
# 591/591 [==============================] - 5s 8ms/step - loss: 0.0205 - val_loss: 0.0053
# Epoch 27/100
# 591/591 [==============================] - 4s 7ms/step - loss: 0.0170 - val_loss: 0.0115
# Epoch 28/100
# 591/591 [==============================] - 5s 9ms/step - loss: 0.0175 - val_loss: 0.0048
# Epoch 29/100
# 591/591 [==============================] - 4s 7ms/step - loss: 0.0112 - val_loss: 0.0079
# Epoch 30/100
# 591/591 [==============================] - 4s 6ms/step - loss: 0.0097 - val_loss: 0.0120
# Epoch 31/100
# 591/591 [==============================] - 5s 8ms/step - loss: 0.0081 - val_loss: 0.0053
# Epoch 32/100
# 591/591 [==============================] - 4s 6ms/step - loss: 0.0078 - val_loss: 0.0054
# Epoch 33/100
# 591/591 [==============================] - 3s 6ms/step - loss: 0.0070 - val_loss: 0.0053
# Epoch 34/100
# 591/591 [==============================] - 3s 6ms/step - loss: 0.0074 - val_loss: 0.0073
# Epoch 35/100
# 591/591 [==============================] - 5s 8ms/step - loss: 0.0078 - val_loss: 0.0056
# Epoch 36/100
# 591/591 [==============================] - 3s 6ms/step - loss: 0.0066 - val_loss: 0.0040
# Epoch 37/100
# 591/591 [==============================] - 3s 5ms/step - loss: 0.0053 - val_loss: 0.0033
# Epoch 38/100
# 591/591 [==============================] - 4s 6ms/step - loss: 0.0053 - val_loss: 0.0040
# Epoch 39/100
# 591/591 [==============================] - 4s 7ms/step - loss: 0.0039 - val_loss: 0.0049
# Epoch 40/100
# 591/591 [==============================] - 3s 6ms/step - loss: 0.0045 - val_loss: 0.0052
# Epoch 41/100
# 591/591 [==============================] - 3s 6ms/step - loss: 0.0034 - val_loss: 0.0049
# Epoch 42/100
# 591/591 [==============================] - 4s 7ms/step - loss: 0.0077 - val_loss: 0.0039
# Epoch 43/100
# 591/591 [==============================] - 4s 7ms/step - loss: 0.0027 - val_loss: 0.0030
# Epoch 44/100
# 591/591 [==============================] - 4s 7ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 45/100
# 591/591 [==============================] - 4s 6ms/step - loss: 0.0023 - val_loss: 0.0042
# Epoch 46/100
# 591/591 [==============================] - 5s 8ms/step - loss: 0.0024 - val_loss: 0.0042
# Epoch 47/100
# 591/591 [==============================] - 4s 6ms/step - loss: 0.0024 - val_loss: 0.0037
# Epoch 48/100
# 591/591 [==============================] - 3s 6ms/step - loss: 0.0024 - val_loss: 0.0079
# Epoch 49/100
# 591/591 [==============================] - 3s 6ms/step - loss: 0.0027 - val_loss: 0.0039
# Epoch 50/100
# 591/591 [==============================] - 5s 8ms/step - loss: 0.0046 - val_loss: 0.0085
# Epoch 51/100
# 591/591 [==============================] - 3s 6ms/step - loss: 0.0039 - val_loss: 0.0154
# Epoch 52/100
# 591/591 [==============================] - 3s 6ms/step - loss: 0.0030 - val_loss: 0.0023
# Epoch 53/100
# 591/591 [==============================] - 3s 6ms/step - loss: 0.0014 - val_loss: 0.0029
# Epoch 54/100
# 591/591 [==============================] - 5s 8ms/step - loss: 0.0012 - val_loss: 0.0070
# Epoch 55/100
# 591/591 [==============================] - 3s 6ms/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 56/100
# 591/591 [==============================] - 3s 6ms/step - loss: 0.0050 - val_loss: 0.0070
# Epoch 57/100
# 591/591 [==============================] - 4s 7ms/step - loss: 0.0032 - val_loss: 0.0021
# Epoch 58/100
# 591/591 [==============================] - 4s 7ms/step - loss: 0.0018 - val_loss: 0.0035
# Epoch 59/100
# 591/591 [==============================] - 3s 6ms/step - loss: 0.0013 - val_loss: 0.0022
# Epoch 60/100
# 591/591 [==============================] - 4s 6ms/step - loss: 0.0016 - val_loss: 0.0023
# Epoch 61/100
# 591/591 [==============================] - 5s 8ms/step - loss: 0.0027 - val_loss: 0.0019
# Epoch 62/100
# 591/591 [==============================] - 3s 6ms/step - loss: 0.0020 - val_loss: 0.0023
# Epoch 63/100
# 591/591 [==============================] - 3s 5ms/step - loss: 0.0010 - val_loss: 0.0021
# Epoch 64/100
# 591/591 [==============================] - 4s 6ms/step - loss: 0.0014 - val_loss: 0.0059
# Epoch 65/100
# 591/591 [==============================] - 5s 8ms/step - loss: 0.0039 - val_loss: 0.0024
# Epoch 66/100
# 591/591 [==============================] - 3s 5ms/step - loss: 9.9818e-04 - val_loss: 0.0025
# Epoch 67/100
# 591/591 [==============================] - 3s 6ms/step - loss: 0.0014 - val_loss: 0.0035
# Epoch 68/100
# 591/591 [==============================] - 4s 7ms/step - loss: 0.0025 - val_loss: 0.0033
# Epoch 69/100
# 591/591 [==============================] - 4s 8ms/step - loss: 0.0047 - val_loss: 0.0024
# Epoch 70/100
# 591/591 [==============================] - 3s 6ms/step - loss: 0.0024 - val_loss: 0.0016
# Epoch 71/100
# 591/591 [==============================] - 3s 6ms/step - loss: 6.4296e-04 - val_loss: 0.0019
# Epoch 72/100
# 591/591 [==============================] - 4s 6ms/step - loss: 8.8265e-04 - val_loss: 0.0013
# Epoch 73/100
# 591/591 [==============================] - 4s 7ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 74/100
# 591/591 [==============================] - 3s 6ms/step - loss: 0.0010 - val_loss: 0.0112
# Epoch 75/100
# 591/591 [==============================] - 3s 6ms/step - loss: 0.0052 - val_loss: 0.0029
# Epoch 76/100
# 591/591 [==============================] - 4s 7ms/step - loss: 9.9590e-04 - val_loss: 0.0013
# Epoch 77/100
# 591/591 [==============================] - 4s 7ms/step - loss: 7.6649e-04 - val_loss: 0.0020
# Epoch 78/100
# 591/591 [==============================] - 4s 6ms/step - loss: 7.0794e-04 - val_loss: 0.0026
# Epoch 79/100
# 591/591 [==============================] - 3s 6ms/step - loss: 9.3118e-04 - val_loss: 0.0019
# Epoch 80/100
# 591/591 [==============================] - 5s 8ms/step - loss: 0.0016 - val_loss: 0.0021
# Epoch 81/100
# 591/591 [==============================] - 4s 6ms/step - loss: 0.0023 - val_loss: 0.0015
# Epoch 82/100
# 591/591 [==============================] - 3s 6ms/step - loss: 0.0011 - val_loss: 0.0019
# Epoch 83/100
# 591/591 [==============================] - 3s 6ms/step - loss: 0.0013 - val_loss: 0.0017
# Epoch 84/100
# 591/591 [==============================] - 5s 8ms/step - loss: 7.5715e-04 - val_loss: 0.0054
# Epoch 85/100
# 591/591 [==============================] - 3s 6ms/step - loss: 0.0021 - val_loss: 0.0078
# Epoch 86/100
# 591/591 [==============================] - 3s 6ms/step - loss: 0.0013 - val_loss: 0.0019
# Epoch 87/100
# 591/591 [==============================] - 4s 6ms/step - loss: 7.5887e-04 - val_loss: 0.0018
# Epoch 88/100
# 591/591 [==============================] - 4s 7ms/step - loss: 8.1520e-04 - val_loss: 0.0013
# Epoch 89/100
# 591/591 [==============================] - 4s 6ms/step - loss: 0.0011 - val_loss: 7.3711e-04
# Epoch 90/100
# 591/591 [==============================] - 4s 6ms/step - loss: 0.0016 - val_loss: 0.0054
# Epoch 91/100
# 591/591 [==============================] - 5s 8ms/step - loss: 9.2563e-04 - val_loss: 0.0024
# Epoch 92/100
# 591/591 [==============================] - 4s 7ms/step - loss: 0.0017 - val_loss: 0.0029
# Epoch 93/100
# 591/591 [==============================] - 3s 6ms/step - loss: 7.6509e-04 - val_loss: 0.0013
# Epoch 94/100
# 591/591 [==============================] - 3s 6ms/step - loss: 7.9275e-04 - val_loss: 0.0013
# Epoch 95/100
# 591/591 [==============================] - 5s 9ms/step - loss: 0.0017 - val_loss: 0.0021
# Epoch 96/100
# 591/591 [==============================] - 3s 6ms/step - loss: 9.8947e-04 - val_loss: 0.0057
# Epoch 97/100
# 591/591 [==============================] - 3s 6ms/step - loss: 0.0012 - val_loss: 0.0019
# Epoch 98/100
# 591/591 [==============================] - 4s 7ms/step - loss: 6.1403e-04 - val_loss: 0.0016
# Epoch 99/100
# 591/591 [==============================] - 5s 8ms/step - loss: 0.0011 - val_loss: 0.0018
# Epoch 100/100
# 591/591 [==============================] - 4s 6ms/step - loss: 0.0011 - val_loss: 0.0016
# 127/127 [==============================] - 0s 3ms/step - loss: 8.0834e-04
# gru model test loss: 0.0008083397406153381

# %%
y_pred = gru_model.predict(x_test)
y_true = y_test
# Out:
# 127/127 [==============================] - 1s 3ms/step

# %%
validation.head()
# Out:
#         ID STORECODE MONTH                       GRP
# 0  1112535        N1    M1       AFTER SHAVE LOTIONS
# 1  1112539        N1    M1    AGARBATTI & DHOOPBATTI
# 2  1112543        N1    M1  ALL AIR FRESHNERS(01/03)
# 3  1112547        N1    M1          ALL IODISED SALT
# 4  1112551        N1    M1                  ANTACIDS

# %%
y_pred_filtered=y_pred[:len(validation['ID'])]

# %%
y_pred_int=np.round(y_pred_filtered).astype(int)
y_pred_int[y_pred_int<0]=0

# %%
submission = pd.DataFrame({'ID':validation['ID'],'TOTAL_VALUE':y_pred_int.flatten()})

# %%
submission.head()
# Out:
#         ID  TOTAL_VALUE
# 0  1112535            0
# 1  1112539            0
# 2  1112543            0
# 3  1112547            0
# 4  1112551            0

# %%
submission.to_csv("submission.csv",index=False)
print("OKAY")
# Out:
# OKAY

# %% [markdown]
# *    Identify peak sales periods and products contributing to high sales.
# *   Examine the frequency of transactions over time.
#
# *   Recognize long-term growth or decline, seasonal patterns, and periodic fluctuations.
# *   Understand how different times of the year affect sales, allowing for better inventory and staffing decisions.
#
# *   Segment customers based on purchase frequency, recency, and monetary value (RFM analysis).
# *   Identify high-value customers and marketing strategies accordingly.
#
# *   Improve cross-selling strategies and product placement in the store.
# *   Understand customer satisfaction and areas needing improvement.
#
# *   Analyze the trends in customer behavior for working data and ideal data.
